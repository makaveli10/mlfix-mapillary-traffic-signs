# %% [markdown]
# # MLfix – using AI and UI to explore and fix datasets

# %% [markdown]
# [![Gitter](https://badges.gitter.im/MLfix/community.svg)](https://gitter.im/MLfix/community?utm_source=badge&utm_medium=badge&utm_campaign=pr-badge) [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/jpc/mlfix-mapillary-traffic-signs/HEAD?labpath=index.ipynb)

# %% [markdown]
# ![A futuristic robot cleaning streets of New York that are overflowing with papers.](banner.jpg)
# Is your dataset overflowing with low quality samples? Our highly-skilled robots can help you! (generated by [Centipede Diffusion](https://github.com/Zalring/Centipede_Diffusion/))
#
# ### Why?
#
# Even carefully curated AI datasets have errors. In a highly curated dataset like the [Mapillary Traffic Sign Dataset](https://www.mapillary.com/dataset/trafficsign) even the easy classes, like speed limits, [have 3% of mislabeled samples](./2.%20Mapillary%20speed-limit%20cleanup.ipynb). [After training this results in a 2% loss of model accuracy on these classes.](./3.%20Did%20it%20help%3F.ipynb#The-results)
#
# ### What?
#
# This repository contains tools which can help you find mistakes in your labels directly from your Jupyter notebook. You just need a folder full of images or an object detection dataset in one of the supported formats. Here is an example of MLfix running inside a Jupyter session:
#
# ![MLfix v2 usage example](https://user-images.githubusercontent.com/107984/184148474-839b8049-fe68-47f0-b4b5-cc83f27dfea8.mp4)
#
# You can also [try it yourself now on Binder](https://mybinder.org/v2/gh/jpc/mlfix-mapillary-traffic-signs/HEAD?labpath=index.ipynb).
#
# ### How?
#
# The tools work by sorting and grouping the images and then showing them in a streamlined user interface. The interface allows you to mark the photos so you can perform your QA process. The images may be easily groupped and sorted by class or other metadata as well as by AI sorting methods like visual similarity or validation loss.
#
# For more background info you can check the talk we gave at OpenSource Summit NA 2022 [video](https://www.youtube.com/watch?v=IS0k8rPVcmY) [slides](OSS%20NA%202022%20presentation.pdf).

# %% [markdown]
# ## Dependencies

# %% [markdown]
# The tool depends on [Pandas](https://pandas.pydata.org), [jupyter-server-proxy](https://jupyter-server-proxy.readthedocs.io/en/latest/) and [CherryPy](https://cherrypy.dev)
# and should work with any JupyterLab or Jupyter Notebook setup. The demos use [fastai](https://docs.fast.ai)
# for data manipulation and model training.
#
# It does not work on Google Collab because I could not figure out a way to expose an HTTP server (needed to serve the images) from the running notebook. I think it could be supported in the future by moving the images to an object storage database (like Amazon S3).

# %% [markdown]
# ### Quick start

# %% [markdown]
# It's easiest to start with any dataset in the ImageNet format (one folder per class) or with just a folder of unsorted pictures. If you have a custom dataset you can look into [the notebook we wrote for the Mapillary dataset](1.%20Generate%20bbox%20crops%20from%20ground%20truth.ipynb). Support for YOLO format is comming soon.
#
# You can also test out the tool on the included traffic sign samples:

# %%
#| eval: false
#| output: false
from fastai.vision.all import *
from MLfix import MLfix

# get all the photos
fnames = get_image_files('./yolo-bbox-crops-aspects-carla/')

# put tham into a DataFrame
data = pd.DataFrame(dict(fname = fnames), index = [str(x) for x in fnames])
# the class label is the parent folder name
data['label'] = data.fname.map(lambda x: x.parent.name)
# show a sample of rows
data.head()
# Out:
#                                                                                                  fname  \
# yolo-bbox-crops-aspects-carla/Cyclist/003345-3.jpg  yolo-bbox-crops-aspects-carla/Cyclist/003345-3.jpg
# yolo-bbox-crops-aspects-carla/Cyclist/001581-1.jpg  yolo-bbox-crops-aspects-carla/Cyclist/001581-1.jpg
# yolo-bbox-crops-aspects-carla/Cyclist/003768-1.jpg  yolo-bbox-crops-aspects-carla/Cyclist/003768-1.jpg
# yolo-bbox-crops-aspects-carla/Cyclist/000950-2.jpg  yolo-bbox-crops-aspects-carla/Cyclist/000950-2.jpg
# yolo-bbox-crops-aspects-carla/Cyclist/002842-0.jpg  yolo-bbox-crops-aspects-carla/Cyclist/002842-0.jpg
#
#                                                       label
# yolo-bbox-crops-aspects-carla/Cyclist/003345-3.jpg  Cyclist
# yolo-bbox-crops-aspects-carla/Cyclist/001581-1.jpg  Cyclist
# yolo-bbox-crops-aspects-carla/Cyclist/003768-1.jpg  Cyclist
# yolo-bbox-crops-aspects-carla/Cyclist/000950-2.jpg  Cyclist
# yolo-bbox-crops-aspects-carla/Cyclist/002842-0.jpg  Cyclist

# %%
#| eval: false
#| output: false 
# run MLfix and save the results into a new variable
new_labels = MLfix(data, label='label')
# Out:
# label
#     <style>
#       .mlfix-container {
#         position: relative;
#         background-color: white;
#       }
#       .mlfix-fullscreen {
#         width: 100%;
#         height: 100%;
#         position: absolute;
#         top: 0;
#         left: 0;
#         z-index: 10000;
#       }
#       .mlfix-fullscreen iframe {
#         height: 100%;
#       }
#     </style>
#     <div id=mlfix-BcM6K-container class=mlfix-container>
#       <iframe id=mlfix-BcM6K src="/proxy/44087/mlfix-BcM6K/#mlfix-BcM6K"
#               width="100%" height="500px" frameborder="0" allowfullscreen></iframe>
#       <script>(function () {
#         var iframe = document.getElementById('mlfix-BcM6K');
#         var outputEl = iframe.parentNode;
#         var parentEl = outputEl.parentNode;
#         console.log('MLfix init:', outputEl, parentEl);
#         var bringMLfixIframeToFocus = function() {
#             iframe.contentWindow.focus();
#         }
#         setTimeout(bringMLfixIframeToFocus, 100);
#
#         var isFullscreen = false;
#         var parentEl;
#         window.addEventListener('message', (ev) => {
#           if (ev.data == 'mlfix-toggle-fullscreen-mlfix-BcM6K') {
#             if (!isFullscreen) {
#               $(outputEl).appendTo(document.body).addClass('mlfix-fullscreen');
#             } else {
#               $(outputEl).appendTo(parentEl).removeClass('mlfix-fullscreen');
#             }
#             isFullscreen = !isFullscreen;
#             console.log('fullscreen', isFullscreen);
#             setTimeout(bringMLfixIframeToFocus, 100);
#           }
#         });
#       })();</script>
#     </div>
# yolo-bbox-crops-aspects-carla/Car/001260-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Car/003109-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Car/004162-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Car/000746-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Car/000421-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Car/003602-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Car/002116-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Car/000389-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Car/001864-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Car/000314-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Car/000678-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Car/000678-1.jpg label = Car
# yolo-bbox-crops-aspects-carla/Car/000198-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001581-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001001-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003693-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003607-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003607-4.jpg label = Cyclist
# yolo-bbox-crops-aspects-carla/Cyclist/003607-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001277-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000636-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000636-0.jpg label = Cyclist
# yolo-bbox-crops-aspects-carla/Cyclist/000636-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003602-6.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000725-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003154-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003348-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000680-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002944-5.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001903-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001703-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001963-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001564-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001174-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000556-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001964-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001250-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000743-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000681-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001142-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000279-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001377-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003227-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000079-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001253-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000079-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001557-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001162-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000935-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001064-5.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000501-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003912-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000123-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000153-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001256-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001536-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001063-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002073-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000430-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001297-6.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000316-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001183-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003904-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002237-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000585-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003704-6.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003224-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002273-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002087-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000215-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000763-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001966-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003347-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000369-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002046-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/004146-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002372-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001975-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001070-6.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000748-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003772-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002327-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000634-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002542-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001962-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003746-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002723-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003159-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003331-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000231-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001361-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000581-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001543-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001238-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003606-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001638-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002086-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001952-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002739-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001252-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001087-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003702-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002011-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001559-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001182-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000014-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003277-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002126-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001661-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000655-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000107-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001296-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001164-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002948-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001204-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002234-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001462-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000910-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000724-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000644-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000644-3.jpg label = Cyclist
# yolo-bbox-crops-aspects-carla/Cyclist/001943-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002050-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001061-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003228-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001000-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000922-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001834-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001567-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000750-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000696-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000584-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000663-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003691-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001300-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002099-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001382-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000547-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001092-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001092-0.jpg label = Cyclist
# yolo-bbox-crops-aspects-carla/Cyclist/000547-2.jpg label = Cyclist
# yolo-bbox-crops-aspects-carla/Cyclist/001300-1.jpg label = Cyclist
# yolo-bbox-crops-aspects-carla/Cyclist/001300-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000547-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001360-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000079-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001839-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000782-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/004158-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000862-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000132-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003705-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000150-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000150-1.jpg label = Cyclist
# yolo-bbox-crops-aspects-carla/Cyclist/000150-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000109-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001635-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001966-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001238-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001582-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001800-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001061-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001095-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/002699-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000276-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000343-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003350-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/000908-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003769-6.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/000422-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002004-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002954-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/000447-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001550-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002766-5.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001903-6.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/003929-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002284-6.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001182-7.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001182-7.jpg label = Pedestrian
# yolo-bbox-crops-aspects-carla/Pedestrian/001858-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002009-6.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002147-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001800-9.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002024-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001922-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001409-6.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001425-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/003841-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001937-5.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/000641-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002064-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/003933-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002020-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/003923-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/003828-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002020-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002402-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/000874-5.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/000155-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/000870-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/000766-5.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/004594-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002637-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/003869-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002121-0.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/000057-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/000370-8.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/004745-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/003045-5.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/003045-5.jpg label = Pedestrian
# yolo-bbox-crops-aspects-carla/Pedestrian/001285-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/000656-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/000318-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/004758-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002146-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001362-6.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002027-4.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/003965-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001937-6.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001060-5.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/000274-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/004917-2.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002085-5.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001348-8.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/000160-1.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/001868-7.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/003901-3.jpg label = invalid
# yolo-bbox-crops-aspects-carla/Pedestrian/002136-1.jpg label = invalid

# %% [markdown]
# After working through the images you can check the results in the returned Pandas Series.

# %%
#| output: false
new_labels[new_labels == 'invalid']
# Out:
# yolo-bbox-crops-aspects-carla/Cyclist/001581-1.jpg    invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001001-2.jpg    invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003607-4.jpg    invalid
# yolo-bbox-crops-aspects-carla/Cyclist/003693-4.jpg    invalid
# yolo-bbox-crops-aspects-carla/Cyclist/001277-0.jpg    invalid
#                                                        ...
# yolo-bbox-crops-aspects-carla/Car/002116-4.jpg        invalid
# yolo-bbox-crops-aspects-carla/Car/000389-0.jpg        invalid
# yolo-bbox-crops-aspects-carla/Car/001864-3.jpg        invalid
# yolo-bbox-crops-aspects-carla/Car/000314-1.jpg        invalid
# yolo-bbox-crops-aspects-carla/Car/000198-0.jpg        invalid
# Name: label, Length: 209, dtype: object

# %%
invalid = new_labels[new_labels == 'invalid']

# %% [markdown]
# For more usage examples and tricks, see the example notebooks in this repository. More examples are comming soon.

# %%
invalid.to_csv('invalid-objects.csv')

# %%
https://localhost:8888/proxy/47739/mlfix-jYHCi/imgs/yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90/002374-0.jpg
# Out:
#   Input In [3]
#     https://localhost:8888/proxy/39765/mlfix-4LBsB/imgs/yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000215-0.jpg
#           ^
# SyntaxError: invalid syntax
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000115-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000227-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000051-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000195-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000080-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000080-0.jpg label = Speed-Limit-30
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000080-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60/000131-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90/000175-0.jpg label = invalid
