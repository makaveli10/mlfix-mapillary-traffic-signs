# %% [markdown]
# # MLfix – using AI and UI to explore and fix datasets

# %% [markdown]
# [![Gitter](https://badges.gitter.im/MLfix/community.svg)](https://gitter.im/MLfix/community?utm_source=badge&utm_medium=badge&utm_campaign=pr-badge) [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/jpc/mlfix-mapillary-traffic-signs/HEAD?labpath=index.ipynb)

# %% [markdown]
# ![A futuristic robot cleaning streets of New York that are overflowing with papers.](banner.jpg)
# Is your dataset overflowing with low quality samples? Our highly-skilled robots can help you! (generated by [Centipede Diffusion](https://github.com/Zalring/Centipede_Diffusion/))
#
# ### Why?
#
# Even carefully curated AI datasets have errors. In a highly curated dataset like the [Mapillary Traffic Sign Dataset](https://www.mapillary.com/dataset/trafficsign) even the easy classes, like speed limits, [have 3% of mislabeled samples](./2.%20Mapillary%20speed-limit%20cleanup.ipynb). [After training this results in a 2% loss of model accuracy on these classes.](./3.%20Did%20it%20help%3F.ipynb#The-results)
#
# ### What?
#
# This repository contains tools which can help you find mistakes in your labels directly from your Jupyter notebook. You just need a folder full of images or an object detection dataset in one of the supported formats. Here is an example of MLfix running inside a Jupyter session:
#
# ![MLfix v2 usage example](https://user-images.githubusercontent.com/107984/184148474-839b8049-fe68-47f0-b4b5-cc83f27dfea8.mp4)
#
# You can also [try it yourself now on Binder](https://mybinder.org/v2/gh/jpc/mlfix-mapillary-traffic-signs/HEAD?labpath=index.ipynb).
#
# ### How?
#
# The tools work by sorting and grouping the images and then showing them in a streamlined user interface. The interface allows you to mark the photos so you can perform your QA process. The images may be easily groupped and sorted by class or other metadata as well as by AI sorting methods like visual similarity or validation loss.
#
# For more background info you can check the talk we gave at OpenSource Summit NA 2022 [video](https://www.youtube.com/watch?v=IS0k8rPVcmY) [slides](OSS%20NA%202022%20presentation.pdf).

# %% [markdown]
# ## Dependencies

# %% [markdown]
# The tool depends on [Pandas](https://pandas.pydata.org), [jupyter-server-proxy](https://jupyter-server-proxy.readthedocs.io/en/latest/) and [CherryPy](https://cherrypy.dev)
# and should work with any JupyterLab or Jupyter Notebook setup. The demos use [fastai](https://docs.fast.ai)
# for data manipulation and model training.
#
# It does not work on Google Collab because I could not figure out a way to expose an HTTP server (needed to serve the images) from the running notebook. I think it could be supported in the future by moving the images to an object storage database (like Amazon S3).

# %% [markdown]
# ### Quick start

# %% [markdown]
# It's easiest to start with any dataset in the ImageNet format (one folder per class) or with just a folder of unsorted pictures. If you have a custom dataset you can look into [the notebook we wrote for the Mapillary dataset](1.%20Generate%20bbox%20crops%20from%20ground%20truth.ipynb). Support for YOLO format is comming soon.
#
# You can also test out the tool on the included traffic sign samples:

# %%
#| eval: false
#| output: false
from fastai.vision.all import *
from MLfix import MLfix

# get all the photos
fnames = get_image_files('./yolo-bbox-crops-aspects-traffic-signs/')

# put tham into a DataFrame
data = pd.DataFrame(dict(fname = fnames), index = [str(x) for x in fnames])
# the class label is the parent folder name
data['label'] = data.fname.map(lambda x: x.parent.name)
# show a sample of rows
data.head()
# Out:
#                                                                                                                                      fname  \
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/002578-0.jpg  yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/002578-0.jpg
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001971-0.jpg  yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001971-0.jpg
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/002348-0.jpg  yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/002348-0.jpg
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001564-0.jpg  yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001564-0.jpg
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001842-1.jpg  yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001842-1.jpg
#
#                                                                                   label
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/002578-0.jpg  Speed-Limit-30-US
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001971-0.jpg  Speed-Limit-30-US
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/002348-0.jpg  Speed-Limit-30-US
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001564-0.jpg  Speed-Limit-30-US
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001842-1.jpg  Speed-Limit-30-US

# %%
#| eval: false
#| output: false 
# run MLfix and save the results into a new variable
new_labels = MLfix(data, label='label')
# Out:
# label
#     <style>
#       .mlfix-container {
#         position: relative;
#         background-color: white;
#       }
#       .mlfix-fullscreen {
#         width: 100%;
#         height: 100%;
#         position: absolute;
#         top: 0;
#         left: 0;
#         z-index: 10000;
#       }
#       .mlfix-fullscreen iframe {
#         height: 100%;
#       }
#     </style>
#     <div id=mlfix-jYHCi-container class=mlfix-container>
#       <iframe id=mlfix-jYHCi src="/proxy/47739/mlfix-jYHCi/#mlfix-jYHCi"
#               width="100%" height="500px" frameborder="0" allowfullscreen></iframe>
#       <script>(function () {
#         var iframe = document.getElementById('mlfix-jYHCi');
#         var outputEl = iframe.parentNode;
#         var parentEl = outputEl.parentNode;
#         console.log('MLfix init:', outputEl, parentEl);
#         var bringMLfixIframeToFocus = function() {
#             iframe.contentWindow.focus();
#         }
#         setTimeout(bringMLfixIframeToFocus, 100);
#
#         var isFullscreen = false;
#         var parentEl;
#         window.addEventListener('message', (ev) => {
#           if (ev.data == 'mlfix-toggle-fullscreen-mlfix-jYHCi') {
#             if (!isFullscreen) {
#               $(outputEl).appendTo(document.body).addClass('mlfix-fullscreen');
#             } else {
#               $(outputEl).appendTo(parentEl).removeClass('mlfix-fullscreen');
#             }
#             isFullscreen = !isFullscreen;
#             console.log('fullscreen', isFullscreen);
#             setTimeout(bringMLfixIframeToFocus, 100);
#           }
#         });
#       })();</script>
#     </div>
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002058-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002725-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002585-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001661-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002724-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001385-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002726-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002586-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002055-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002057-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001475-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001476-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002587-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002338-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001660-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002091-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001659-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001474-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002584-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001384-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002056-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002092-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001599-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002054-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002268-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002727-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002727-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002268-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002054-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002054-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001599-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002092-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001384-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001384-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002056-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002056-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002584-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002584-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001474-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001474-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001659-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001659-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002091-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001660-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001475-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002057-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002057-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002338-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002338-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002338-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002587-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001476-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002726-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002726-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002055-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002586-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002586-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002055-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001385-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001385-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002724-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002724-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001661-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002585-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002585-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002725-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002725-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002058-0.jpg label = Lane-Reduce-Left
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002058-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002152-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002156-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002294-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001621-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001984-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002292-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002563-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002559-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001626-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002177-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001999-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001997-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001991-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002759-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001939-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002284-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002630-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001985-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002011-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002157-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001993-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001800-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002043-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001940-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002561-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002293-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002153-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001990-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002564-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001622-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001803-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001983-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002204-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002202-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001829-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002013-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002286-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001619-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001986-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001880-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002280-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002424-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002242-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002421-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002365-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001905-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001887-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002158-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002158-0.jpg label = No-Turns
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001989-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001996-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002027-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002203-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002017-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001988-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002028-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002018-2.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001941-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001726-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002174-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002606-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001802-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001942-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001992-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001982-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001642-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001727-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002010-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001624-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002155-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001644-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002288-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001625-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002760-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002757-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001620-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002562-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002631-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001850-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001801-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001623-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001617-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001618-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002560-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002014-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001641-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002758-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002566-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002287-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001995-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/002285-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001987-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001804-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/No-Turns/001998-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/One-Way/002628-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/One-Way/002626-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/One-Way/002627-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/One-Way-Left/002618-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001842-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/002161-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001841-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001498-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001844-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/002741-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001500-2.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001969-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/002258-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001843-2.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/002697-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/001597-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/002267-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/002262-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/002609-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/002224-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/001852-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/001711-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/001477-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/002698-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/002246-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/001561-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/001561-0.jpg label = Speed-Limit-40
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/001561-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/001851-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/002638-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/002679-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/002610-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-40/002198-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002120-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001593-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001594-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002121-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002045-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002053-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001956-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002486-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001955-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001592-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002232-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002050-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001687-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002377-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001577-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002103-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001501-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001501-0.jpg label = Speed-Limit-60-US
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002482-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001899-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002118-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002129-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001900-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001949-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002485-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001927-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001578-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001820-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002702-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001819-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001928-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/001841-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60-US/002049-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90/001891-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90/001891-0.jpg label = Speed-Limit-90
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90/001891-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90/001891-0.jpg label = Speed-Limit-90
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90/001891-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/002608-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/001382-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/001597-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/002124-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/002128-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/002557-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/002392-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/002617-1.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/001596-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/002453-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/002581-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/001605-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/002415-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/002414-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/002095-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/002579-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90-US/001815-0.jpg label = invalid

# %% [markdown]
# After working through the images you can check the results in the returned Pandas Series.

# %%
#| output: false
new_labels[new_labels == 'invalid']
# Out:
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001842-1.jpg    invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/002161-0.jpg    invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001841-0.jpg    invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001498-0.jpg    invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30-US/001844-0.jpg    invalid
#                                                                          ...
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001474-0.jpg     invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002584-0.jpg     invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/001384-0.jpg     invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002056-0.jpg     invalid
# yolo-bbox-crops-aspects-traffic-signs/Lane-Reduce-Left/002054-0.jpg     invalid
# Name: label, Length: 187, dtype: object

# %%
invalid = new_labels[new_labels == 'invalid']

# %% [markdown]
# For more usage examples and tricks, see the example notebooks in this repository. More examples are comming soon.

# %%
invalid.to_csv('invalid-traffic-signs.csv')
# Out:
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90/001891-0.jpg label = Speed-Limit-90
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90/002374-0.jpg label = invalid

# %%
https://localhost:8888/proxy/47739/mlfix-jYHCi/imgs/yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90/002374-0.jpg
# Out:
#   Input In [3]
#     https://localhost:8888/proxy/39765/mlfix-4LBsB/imgs/yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000215-0.jpg
#           ^
# SyntaxError: invalid syntax
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000115-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000227-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000051-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000195-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000080-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000080-0.jpg label = Speed-Limit-30
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-30/000080-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-60/000131-0.jpg label = invalid
# yolo-bbox-crops-aspects-traffic-signs/Speed-Limit-90/000175-0.jpg label = invalid
